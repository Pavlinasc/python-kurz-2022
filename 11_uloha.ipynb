# %%
import pandas

# %%
platy = pandas.read_csv('platy_2021_02.csv')
platy.head()
#platy.plot()
# Out:
# <Axes: >

# %%
platy['plat'].plot(kind='hist', bins=30, grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
platy['plat'].plot(kind='hist', bins=20, title='Rozdelenie platov', xlabel='Plat', ylabel='ID Zam')
# Out:
# <Axes: title={'center': 'Rozdelenie platov'}, ylabel='Frequency'>
